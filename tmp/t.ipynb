# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Sex': ['male','female', 'male'],
    'Alive': [True, np.nan, False],
    'Age': [18, 22, np.nan]
}
df = pd.DataFrame(data)
print(df)

df.fillna(-1)
print(df.fillna(-1))
# Out:
#       Sex  Alive   Age
# 0    male   True  18.0
# 1  female    NaN  22.0
# 2    male  False   NaN
#       Sex  Alive   Age
# 0    male   True  18.0
# 1  female     -1  22.0
# 2    male  False  -1.0

# %%
t =

# %%
df[pd.isna(df).values]
# Out:
#       Sex  Alive   Age
# 1  female    NaN  22.0
# 2    male  False   NaN

# %%
f = df[pd.isna(df).values]
print(f)
# Out:
#       Sex  Alive   Age
# 1  female    NaN  22.0
# 2    male  False   NaN

# %%
df
# Out:
#       Sex  Alive   Age
# 0    male   True  18.0
# 1  female    NaN  22.0
# 2    male  False   NaN

# %%
for i in df[['Age']].index:
    if pd.notna(df[['Age']].iloc[i].item()):
        df.at[i ,'Age'] = 1

# %%
df
# Out:
#       Sex  Alive  Age
# 0    male   True  1.0
# 1  female    NaN  1.0
# 2    male  False  NaN
