# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Two major styles

# %% [markdown]
# Matplotlib has two major application interfaces, or styles of using the library:
#
# - An explicit "Axes" interface that uses methods on a Figure or Axes object to create other Artists, and build a visualization step by step. This has also been called an "object-oriented" interface.
#
# - An implicit "pyplot" interface that keeps track of the last Figure and Axes created, and adds Artists to the object it thinks the user wants.

# %%
# exlicit Axes
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.subplots()
ax.plot([1, 2, 3, 4], [0, 0.5, 1, 0.2])

# %%
# implicit pyplot
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [0, 0.5, 1, 0.2])

# %% [markdown]
# # Comparison

# %%
fig = plt.figure()
ax = fig.subplots()

# %%
fig, ax = plt.subplots(figsize=(2, 2))

fig, axs = plt.subplots(1, 2)
axs[0].plot([1, 2, 3], [0, 0.5, 0.2])
axs[1].plot([3, 2, 1], [0, 0.5, 0.2])

# %%
import matplotlib.pyplot as plt

plt.subplot(1, 2, 1)
plt.plot([1, 2, 3], [0, 0.5, 0.2])

plt.subplot(1, 2, 2)
plt.plot([3, 2, 1], [0, 0.5, 0.2])

# %%
import matplotlib.pyplot as plt

ax = plt.subplot(1, 2, 1)
ax.plot([1, 2, 3], [0, 0.5, 0.2])

ax = plt.subplot(1, 2, 2)
ax.plot([3, 2, 1], [0, 0.5, 0.2])

plt.gcf().set_suptitle('Implicit Interface: save handles')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [57], in <cell line: 9>()
#       6 ax = plt.subplot(1, 2, 2)
#       7 ax.plot([3, 2, 1], [0, 0.5, 0.2])
# ----> 9 plt.gcf().set_suptitle('Implicit Interface: save handles')
#
# AttributeError: 'Figure' object has no attribute 'set_suptitle'

# %% [markdown]
# |plt|ax|fig|
# |:-|:-|:-|
# ||`plt.gca`|`plt.gcf`|
# |`plt.plot`|`ax.plot`|
# |`plt.title`|`ax.set_title`|
# |`plt.suptitle`||`fig.suptitle`|
# |`plt.xlabel`|`ax.set_xlabel`|
# |`plt.xscale`|`ax.set_xscale`|
# |`plt.xlim`|`ax.xlim`|
# |`plt.legend`|`ax.legend`|
# |`plt.grid`|`ax.grid`|

# %%
# get current axes, 当前有 Axes 就用, 没有就生成一个并返回
ax = plt.gca()
ax.plot([1, 2, 3, 4], [0, 0.5, 1, 0.2])

# %%
x = np.arange(0, 3, 0.1)
y = 3 * x ** 2 - 4 * x
z = 2 * x - 3

# %%
ax = plt.gca()
ax.plot(x,y)
ax.plot(x,z)
ax.legend(['f(x)', 'Tangent line (x=1)'])
